# %%
import os

# %%
pwd
# Out:
# 'e:\\work\\project mlops\\Chatbot1\\Chatbot'

# %%
os.chdir('../')

# %%
import pandas as pd

# %%
df=pd.read_csv("artifacts\model_evaluation\predictions.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Abdullah Ali\AppData\Local\Temp\ipykernel_14656\866916775.py:1: SyntaxWarning: invalid escape sequence '\m'
#   df=pd.read_csv("artifacts\model_evaluation\predictions.csv")

# %%
df.head()
# Out:
#                                                Input  \
# 0  the table structure is: create table classroom...
# 1  SELECT buildingnFROM classroomnWHERE capacity ...
# 2  the table structure is: create table classroom...
# 3  I'm sorry, but the table structure and questio...
# 4  the table structure is: create table classroom...
#
#                                               Target  \
# 0  SELECT buildingnFROM classroomnWHERE capacity ...
# 1  the table structure is: create table classroom...
# 2  I'm sorry, but the table structure and questio...
# 3  the table structure is: create table classroom...
# 4  To answer this question, you would need to kno...
#
#                                           Prediction
# 0  Table structure is: create table classroomn (b...
# 1  SELECT buildingnFROM classroomnWHERE capacity ...
# 2  The table structure is: create table classroom...
# 3  I'm sorry, but the table structure and questio...
# 4  The table structure is: create table classroom...

# %%
df['Input'][0]
# Out:
# 'the table structure is: create table classroomn (building varchar(15) comment \'\',n room_number varchar(7) comment \'\',n capacity numeric(4,0) comment \'\',n primary key (building, room_number)n ) comment=\'\';n;the question is: Find the buildings which have rooms with capacity more than 50.convert to sql according to the table structure and question prompt",'

# %%
df['Target'][0]
# Out:
# "SELECT buildingnFROM classroomnWHERE capacity > 50;',"

# %%
df['Prediction'][0]
# Out:
# 'Table structure is: create table classroomn (building varchar(15) comment \'\',n room_number varchar(7) comment \'\',n capacity numeric(4,0) comment \'\',n primary key (building, room_number)n ) comment=\'\';n;the question is: Find the buildings which have rooms with capacity more than 50.convert to sql according to the table structure and question prompt".'

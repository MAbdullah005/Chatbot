# %%
import os

# %%
pwd
# Out:
# 'e:\\work\\project mlops\\Chatbot1\\Chatbot\\research'

# %%
os.chdir('../')

# %%
import pandas as pd

# %%
df=pd.read_csv("artifacts\model_evaluation\predictions.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Abdullah Ali\AppData\Local\Temp\ipykernel_6372\866916775.py:1: SyntaxWarning: invalid escape sequence '\m'
#   df=pd.read_csv("artifacts\model_evaluation\predictions.csv")

# %%
df.head()
# Out:
#                                                Input  \
# 0  Convert the following question to SQL: the tab...
# 1  Convert the following question to SQL: SELECT ...
# 2  Convert the following question to SQL: the tab...
# 3  Convert the following question to SQL: I'm sor...
# 4  Convert the following question to SQL: the tab...
#
#                                               Target  \
# 0  SELECT building FROM classroom WHERE capacity ...
# 1  the table structure is: create table classroom...
# 2  I'm sorry, but the table structure and questio...
# 3  the table structure is: create table classroom...
# 4  To answer this question, you would need to kno...
#
#                                           Prediction
# 0  to sql according to the table structure and qu...
# 1  Convert the following question to SQL: SELECT ...
# 2  Convert the following question to SQL: create ...
# 3  the following question to SQL: I'm sorry, but ...
# 4  Convert the following question to SQL: create ...

# %%
df['Input'][0]
# Out:
# "Convert the following question to SQL: the table structure is: create table classroom (building varchar(15) comment '', room_number varchar(7) comment '', capacity numeric(4,0) comment '', primary key (building, room_number) ) comment=''; ;the question is: Find the buildings which have rooms with capacity more than 50.convert to sql according to the table structure and question prompt"

# %%
df['Target'][0]
# Out:
# 'SELECT building FROM classroom WHERE capacity > 50;'

# %%
df['Prediction'][0]
# Out:
# "to sql according to the table structure and question prompt: create table classroom (building varchar(15) comment '', room_number varchar(7) comment '', capacity numeric(4,0) comment '', primary key (building, room_number) ) comment='';the question is: Find the buildings which have rooms with capacity more than 50.convert to sql according to the table structure and question prompt: create table classroom (building varchar(15) comment"
